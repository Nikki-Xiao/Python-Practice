# %% [markdown]
# # Practice referring to the course by "Corey Schafer" in YTB

# %%
import pandas as pd

# %% [markdown]
# ## **Basically read and select**

# %%
df = pd.read_csv('data/survey_results_public.csv', encoding='utf-8')
df_schema = pd.read_csv('data/survey_results_schema.csv')

# %%
#set all the col/rows display count
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head(3).tail(1)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 2           3  I agree  I am a developer by profession  45-54 years old
#
#             Employment                            RemoteWork  \
# 2  Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# 2  Hobby;Professional development or self-paced l...
#
#                                         EdLevel  \
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 2  Books / Physical media;Colleague;On the job tr...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 2  Formal documentation provided by the owner of ...                  NaN
#
#   YearsCode YearsCodePro              DevType                   OrgSize  \
# 2        27           23  Developer, back-end  5,000 to 9,999 employees
#
#        PurchaseInfluence      TechList  \
# 2  I have some influence  Given a list
#
#                                           BuyNewTool  \
# 2  Start a free trial;Ask developers I know/work ...
#
#                     Country                   Currency  CompTotal  \
# 2  United States of America  USD\tUnited States dollar   250000.0
#
#        LanguageHaveWorkedWith LanguageWantToWorkWith DatabaseHaveWorkedWith  \
# 2  Bash/Shell (all shells);Go     Haskell;OCaml;Rust                    NaN
#
#   DatabaseWantToWorkWith                             PlatformHaveWorkedWith  \
# 2                    NaN  Amazon Web Services (AWS);Google Cloud;OpenSta...
#
#   PlatformWantToWorkWith WebframeHaveWorkedWith WebframeWantToWorkWith  \
# 2                    NaN                    NaN                    NaN
#
#   MiscTechHaveWorkedWith MiscTechWantToWorkWith  \
# 2                    NaN                    NaN
#
#             ToolsTechHaveWorkedWith ToolsTechWantToWorkWith  \
# 2  Cargo;Docker;Kubernetes;Make;Nix    Cargo;Kubernetes;Nix
#
#   NEWCollabToolsHaveWorkedWith NEWCollabToolsWantToWorkWith  \
# 2                  Emacs;Helix                  Emacs;Helix
#
#          OpSysPersonal use    OpSysProfessional use  \
# 2  MacOS;Other Linux-based  MacOS;Other Linux-based
#
#            OfficeStackAsyncHaveWorkedWith OfficeStackAsyncWantToWorkWith  \
# 2  Markdown File;Stack Overflow for Teams                  Markdown File
#
#   OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 2    Microsoft Teams;Slack;Zoom                    Slack;Zoom
#
#   AISearchHaveWorkedWith AISearchWantToWorkWith AIDevHaveWorkedWith  \
# 2                    NaN                    NaN                 NaN
#
#   AIDevWantToWorkWith                                         NEWSOSites  \
# 2                 NaN  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                        SOVisitFreq SOAccount  \
# 2  A few times per month or weekly       Yes
#
#                             SOPartFreq   SOComm SOAI                 AISelect  \
# 2  Less than once per month or monthly  Neutral  NaN  No, and I don't plan to
#
#   AISent AIAcc AIBen AIToolInterested in Using AIToolCurrently Using  \
# 2    NaN   NaN   NaN                       NaN                   NaN
#
#   AIToolNot interested in Using AINextVery different  \
# 2                           NaN                  NaN
#
#   AINextNeither different nor similar AINextSomewhat similar  \
# 2                                 NaN                    NaN
#
#   AINextVery similar AINextSomewhat different TBranch                  ICorPM  \
# 2                NaN                      NaN     Yes  Individual contributor
#
#    WorkExp     Knowledge_1                 Knowledge_2 Knowledge_3  \
# 2     23.0  Strongly agree  Neither agree nor disagree       Agree
#
#   Knowledge_4 Knowledge_5 Knowledge_6 Knowledge_7 Knowledge_8  \
# 2       Agree       Agree       Agree       Agree       Agree
#
#          Frequency_1        Frequency_2       Frequency_3  \
# 2  6-10 times a week  6-10 times a week  3-5 times a week
#
#          TimeSearching        TimeAnswering  \
# 2  30-60 minutes a day  30-60 minutes a day
#
#                                     ProfessionalTech  \
# 2  DevOps function;Microservices;Automated testin...
#
#                                             Industry           SurveyLength  \
# 2  Information Services, IT, Software Development...  Appropriate in length
#
#   SurveyEase  ConvertedCompYearly
# 2       Easy             250000.0

# %%
df[['ResponseId','Employment']].head()
# Out:
#    ResponseId                                         Employment
# 0           1                                                NaN
# 1           2                                Employed, full-time
# 2           3                                Employed, full-time
# 3           4                                Employed, full-time
# 4           5  Employed, full-time;Independent contractor, fr...

# %%
df.iloc[0:3,0:3]
# Out:
#    ResponseId     Q120                      MainBranch
# 0           1  I agree                   None of these
# 1           2  I agree  I am a developer by profession
# 2           3  I agree  I am a developer by profession

# %%
df.loc[0:3,'ResponseId':'MainBranch']
# Out:
#    ResponseId     Q120                      MainBranch
# 0           1  I agree                   None of these
# 1           2  I agree  I am a developer by profession
# 2           3  I agree  I am a developer by profession
# 3           4  I agree  I am a developer by profession

# %% [markdown]
# ## **Indexes**  --loc by lable, iloc/loc by default integer index

# %%
df_schema = pd.read_csv('data/survey_results_schema.csv',index_col='qname')
#use loc[] to quicly search by lable index besides int index
df_schema.loc['Knowledge_8','question']
# Out:
# "I feel like I have the tools and/or resources to quickly understand and work on any area of my company's code/system/platform."

# %%
df_schema.sort_index(ascending=False,inplace=True)
df_schema.head()
# Out:
#                  qid                                           question  \
# qname
# YearsCodePro   QID34  NOT including education, how many years have y...
# YearsCode      QID32  Including any education, how many years have y...
# WorkExp       QID288  How many years of working experience do you have?
# Webframe      QID264  Which <b>web frameworks and web technologies</...
# ToolsTech     QID275  Which <b>developer </b><strong>tools for compi...
#
#              force_resp    type selector
# qname
# YearsCodePro      False      MC       DL
# YearsCode         False      MC       DL
# WorkExp           False  Slider  HSLIDER
# Webframe          False  Matrix   Likert
# ToolsTech         False  Matrix   Likert

# %% [markdown]
# ## Filter

# %%
#see what the data looks like
df['ConvertedCompYearly'].value_counts()
# Out:
# 64254.0     315
# 53545.0     234
# 74963.0     213
# 85672.0     203
# 107090.0    197
#            ...
# 83291.0       1
# 11752.0       1
# 875.0         1
# 1033.0        1
# 84761.0       1
# Name: ConvertedCompYearly, Length: 4360, dtype: int64

# %%
#1) filter hign comp yearly data
filt_high_comp = df['ConvertedCompYearly'] > 70000
df[filt_high_comp].head(3) #use df[filt] to return the full dataframe
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork  \
# 1  Employed, full-time                                Remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
#
#                                         EdLevel  \
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 1  Books / Physical media;Colleague;Friend or fam...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Colleague;Friend or family member;Other online...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 1  Formal documentation provided by the owner of ...                Other
# 2  Formal documentation provided by the owner of ...                  NaN
# 3  Formal documentation provided by the owner of ...                  NaN
#
#   YearsCode YearsCodePro                               DevType  \
# 1        18            9  Senior Executive (C-Suite, VP, etc.)
# 2        27           23                   Developer, back-end
# 3        12            7                  Developer, front-end
#
#                     OrgSize                 PurchaseInfluence      TechList  \
# 1          2 to 9 employees  I have a great deal of influence   Investigate
# 2  5,000 to 9,999 employees             I have some influence  Given a list
# 3      100 to 499 employees             I have some influence   Investigate
#
#                                           BuyNewTool  \
# 1  Start a free trial;Ask developers I know/work ...
# 2  Start a free trial;Ask developers I know/work ...
# 3  Start a free trial;Ask developers I know/work ...
#
#                     Country                   Currency  CompTotal  \
# 1  United States of America  USD\tUnited States dollar   285000.0
# 2  United States of America  USD\tUnited States dollar   250000.0
# 3  United States of America  USD\tUnited States dollar   156000.0
#
#                               LanguageHaveWorkedWith  \
# 1                         HTML/CSS;JavaScript;Python
# 2                         Bash/Shell (all shells);Go
# 3  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
#
#                               LanguageWantToWorkWith DatabaseHaveWorkedWith  \
# 1  Bash/Shell (all shells);C#;Dart;Elixir;GDScrip...               Supabase
# 2                                 Haskell;OCaml;Rust                    NaN
# 3  Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...       PostgreSQL;Redis
#
#                 DatabaseWantToWorkWith  \
# 1  Firebase Realtime Database;Supabase
# 2                                  NaN
# 3                     PostgreSQL;Redis
#
#                               PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 1           Amazon Web Services (AWS);Netlify;Vercel  Fly.io;Netlify;Render
# 2  Amazon Web Services (AWS);Google Cloud;OpenSta...                    NaN
# 3                                  Cloudflare;Heroku      Cloudflare;Heroku
#
#                          WebframeHaveWorkedWith  \
# 1                    Next.js;React;Remix;Vue.js
# 2                                           NaN
# 3  Node.js;React;Ruby on Rails;Vue.js;WordPress
#
#                  WebframeWantToWorkWith       MiscTechHaveWorkedWith  \
# 1  Deno;Elm;Nuxt.js;React;Svelte;Vue.js  Electron;React Native;Tauri
# 2                                   NaN                          NaN
# 3          Node.js;Ruby on Rails;Vue.js                          NaN
#
#                           MiscTechWantToWorkWith  \
# 1  Capacitor;Electron;Tauri;Uno Platform;Xamarin
# 2                                            NaN
# 3                                            NaN
#
#                        ToolsTechHaveWorkedWith  \
# 1  Docker;Kubernetes;npm;Pip;Vite;Webpack;Yarn
# 2             Cargo;Docker;Kubernetes;Make;Nix
# 3               Homebrew;npm;Vite;Webpack;Yarn
#
#                              ToolsTechWantToWorkWith  \
# 1  Godot;npm;pnpm;Unity 3D;Unreal Engine;Vite;Web...
# 2                               Cargo;Kubernetes;Nix
# 3                                  Homebrew;npm;Vite
#
#                     NEWCollabToolsHaveWorkedWith NEWCollabToolsWantToWorkWith  \
# 1                         Vim;Visual Studio Code       Vim;Visual Studio Code
# 2                                    Emacs;Helix                  Emacs;Helix
# 3  IntelliJ IDEA;Vim;Visual Studio Code;WebStorm   IntelliJ IDEA;Vim;WebStorm
#
#                                    OpSysPersonal use  \
# 1  iOS;iPadOS;MacOS;Windows;Windows Subsystem for...
# 2                            MacOS;Other Linux-based
# 3                                   iOS;iPadOS;MacOS
#
#                              OpSysProfessional use  \
# 1  MacOS;Windows;Windows Subsystem for Linux (WSL)
# 2                          MacOS;Other Linux-based
# 3                                 iOS;iPadOS;MacOS
#
#                       OfficeStackAsyncHaveWorkedWith  \
# 1  Asana;Basecamp;GitHub Discussions;Jira;Linear;...
# 2             Markdown File;Stack Overflow for Teams
# 3                                               Jira
#
#             OfficeStackAsyncWantToWorkWith  \
# 1  GitHub Discussions;Linear;Notion;Trello
# 2                            Markdown File
# 3                                     Jira
#
#                        OfficeStackSyncHaveWorkedWith  \
# 1  Cisco Webex Teams;Discord;Google Chat;Google M...
# 2                         Microsoft Teams;Slack;Zoom
# 3     Discord;Google Meet;Microsoft Teams;Slack;Zoom
#
#     OfficeStackSyncWantToWorkWith AISearchHaveWorkedWith  \
# 1       Discord;Signal;Slack;Zoom                ChatGPT
# 2                      Slack;Zoom                    NaN
# 3  Discord;Google Meet;Slack;Zoom                    NaN
#
#   AISearchWantToWorkWith AIDevHaveWorkedWith AIDevWantToWorkWith  \
# 1       ChatGPT;Neeva AI      GitHub Copilot      GitHub Copilot
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
#
#                                           NEWSOSites  \
# 1                      Stack Overflow;Stack Exchange
# 2  Stack Overflow;Stack Exchange;Stack Overflow f...
# 3                      Stack Overflow;Stack Exchange
#
#                        SOVisitFreq SOAccount  \
# 1            Daily or almost daily       Yes
# 2  A few times per month or weekly       Yes
# 3             A few times per week       Yes
#
#                             SOPartFreq           SOComm  \
# 1      A few times per month or weekly  Yes, definitely
# 2  Less than once per month or monthly          Neutral
# 3  Less than once per month or monthly   No, not really
#
#                                                 SOAI                 AISelect  \
# 1  I don't think it's super necessary, but I thin...                      Yes
# 2                                                NaN  No, and I don't plan to
# 3            I'm wearing of Stack Overflow using AI.  No, and I don't plan to
#
#         AISent                   AIAcc              AIBen  \
# 1  Indifferent  Other (please explain)  Somewhat distrust
# 2          NaN                     NaN                NaN
# 3          NaN                     NaN                NaN
#
#                            AIToolInterested in Using  \
# 1  Learning about a codebase;Writing code;Debuggi...
# 2                                                NaN
# 3                                                NaN
#
#                         AIToolCurrently Using AIToolNot interested in Using  \
# 1  Writing code;Committing and reviewing code                           NaN
# 2                                         NaN                           NaN
# 3                                         NaN                           NaN
#
#   AINextVery different AINextNeither different nor similar  \
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
#
#   AINextSomewhat similar AINextVery similar AINextSomewhat different TBranch  \
# 1                    NaN                NaN                      NaN     Yes
# 2                    NaN                NaN                      NaN     Yes
# 3                    NaN                NaN                      NaN     Yes
#
#                    ICorPM  WorkExp     Knowledge_1  \
# 1          People manager     10.0  Strongly agree
# 2  Individual contributor     23.0  Strongly agree
# 3  Individual contributor      7.0  Strongly agree
#
#                   Knowledge_2     Knowledge_3     Knowledge_4 Knowledge_5  \
# 1                       Agree  Strongly agree           Agree       Agree
# 2  Neither agree nor disagree           Agree           Agree       Agree
# 3           Strongly disagree  Strongly agree  Strongly agree       Agree
#
#                   Knowledge_6 Knowledge_7     Knowledge_8        Frequency_1  \
# 1                       Agree       Agree  Strongly agree   1-2 times a week
# 2                       Agree       Agree           Agree  6-10 times a week
# 3  Neither agree nor disagree       Agree           Agree   1-2 times a week
#
#          Frequency_2       Frequency_3        TimeSearching  \
# 1   10+ times a week             Never  15-30 minutes a day
# 2  6-10 times a week  3-5 times a week  30-60 minutes a day
# 3   10+ times a week  1-2 times a week  15-30 minutes a day
#
#          TimeAnswering                                   ProfessionalTech  \
# 1  15-30 minutes a day  DevOps function;Microservices;Automated testin...
# 2  30-60 minutes a day  DevOps function;Microservices;Automated testin...
# 3  30-60 minutes a day  Automated testing;Continuous integration (CI) ...
#
#                                             Industry           SurveyLength  \
# 1  Information Services, IT, Software Development...  Appropriate in length
# 2  Information Services, IT, Software Development...  Appropriate in length
# 3                                                NaN  Appropriate in length
#
#   SurveyEase  ConvertedCompYearly
# 1       Easy             285000.0
# 2       Easy             250000.0
# 3       Easy             156000.0

# %%
#use loc to return the specify column 
df.loc[filt_high_comp,'ConvertedCompYearly'].head(3)
# Out:
# 1    285000.0
# 2    250000.0
# 3    156000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
#2) filter age range, by using "isin"
df['Age'].value_counts()
# Out:
# 25-34 years old       11304
# 35-44 years old        7105
# 18-24 years old        5013
# 45-54 years old        2559
# 55-64 years old         945
# Under 18 years old      845
# 65 years or older       302
# Prefer not to say       117
# Name: Age, dtype: int64

# %%
age_rng = ['25-34 years old','35-44 years old']
filt_age_rng = df['Age'].isin(age_rng)

# %%
df.loc[filt_age_rng, 'Age'].value_counts()
# Out:
# 25-34 years old    11304
# 35-44 years old     7105
# Name: Age, dtype: int64

# %%
#3) filter LearnCode, by using "str.contains"
filt_learn_code = df['LearnCode'].str.contains('Book',na=False) #NaN to be false

# %%
df.loc[filt_learn_code,['LearnCode','Age']].head(3)
# Out:
#                                            LearnCode              Age
# 1  Books / Physical media;Colleague;Friend or fam...  25-34 years old
# 2  Books / Physical media;Colleague;On the job tr...  45-54 years old
# 4  Books / Physical media;Online Courses or Certi...  25-34 years old

# %% [markdown]
# ## Modifying Data (row/column)

# %%
#get the subset dataframe
df_mod = df[['ResponseId','Age','EdLevel','YearsCode','DevType','SOAccount']]

# %%
#get the data by iloc/loc/at 
print(df_mod.iloc[2,2].upper())
print(df_mod.at[3,'EdLevel'].upper())
df_mod.iloc[2,2] = df_mod.iloc[2,2].upper()
df_mod.at[3,'EdLevel'] = df_mod.at[3,'EdLevel'].upper()
df_mod.iloc[1:4]
# Out:
# BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)
# BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)
#    ResponseId              Age                                       EdLevel  \
# 1           2  25-34 years old  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           3  45-54 years old  BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)
# 3           4  25-34 years old  BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)
#
#   YearsCode                               DevType SOAccount
# 1        18  Senior Executive (C-Suite, VP, etc.)       Yes
# 2        27                   Developer, back-end       Yes
# 3        12                  Developer, front-end       Yes

# %%
#apply: apply the func to series/dataframe objects
#1) series
df_mod.dtypes
df_mod['Age'].apply(len)
# Out:
# 0        15
# 1        15
# 2        15
# 3        15
# 4        15
#          ..
# 28185    15
# 28186    15
# 28187    15
# 28188    17
# 28189    15
# Name: Age, Length: 28190, dtype: int64

# %%
df_mod.apply(len)
# Out:
# ResponseId    28190
# Age           28190
# EdLevel       28190
# YearsCode     28190
# DevType       28190
# SOAccount     28190
# dtype: int64

# %%
df_mod.astype(str).applymap(str.upper)
# Out:
#       ResponseId                Age  \
# 0              1    18-24 YEARS OLD
# 1              2    25-34 YEARS OLD
# 2              3    45-54 YEARS OLD
# 3              4    25-34 YEARS OLD
# 4              5    25-34 YEARS OLD
# ...          ...                ...
# 28185      28186    25-34 YEARS OLD
# 28186      28187    45-54 YEARS OLD
# 28187      28188    18-24 YEARS OLD
# 28188      28189  65 YEARS OR OLDER
# 28189      28190    25-34 YEARS OLD
#
#                                                  EdLevel YearsCode  \
# 0                                                    NAN       NAN
# 1           BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)        18
# 2           BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)        27
# 3           BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)        12
# 4           BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)         6
# ...                                                  ...       ...
# 28185       BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)       NAN
# 28186  SOME COLLEGE/UNIVERSITY STUDY WITHOUT EARNING ...        30
# 28187     PROFESSIONAL DEGREE (JD, MD, PH.D, ED.D, ETC.)         7
# 28188    MASTER’S DEGREE (M.A., M.S., M.ENG., MBA, ETC.)        41
# 28189       BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)        20
#
#                                     DevType SOAccount
# 0                                       NAN       NAN
# 1      SENIOR EXECUTIVE (C-SUITE, VP, ETC.)       YES
# 2                       DEVELOPER, BACK-END       YES
# 3                      DEVELOPER, FRONT-END       YES
# 4                     DEVELOPER, FULL-STACK        NO
# ...                                     ...       ...
# 28185                   DEVELOPER, BACK-END       YES
# 28186                 DEVELOPER, FULL-STACK       YES
# 28187                                   NAN       YES
# 28188                 DEVELOPER, FULL-STACK       YES
# 28189                 DEVELOPER, FULL-STACK       YES
#
# [28190 rows x 6 columns]

# %%
df_mod['SOAccount'].astype(str).map({'Yes':True,'No':False})
# Out:
# 0          NaN
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 28185     True
# 28186     True
# 28187     True
# 28188     True
# 28189     True
# Name: SOAccount, Length: 28190, dtype: object

# %%
df_mod['SOAccount'].astype(str).replace({'Yes':True,'No':False})
# Out:
# 0          nan
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 28185     True
# 28186     True
# 28187     True
# 28188     True
# 28189     True
# Name: SOAccount, Length: 28190, dtype: object

# %% [markdown]
# ## Alter table (row/column)

# %%
df_mod.head()
# Out:
#    ResponseId              Age                                       EdLevel  \
# 0           1  18-24 years old                                           NaN
# 1           2  25-34 years old  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           3  45-54 years old  BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)
# 3           4  25-34 years old  BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)
# 4           5  25-34 years old  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#   YearsCode                               DevType SOAccount
# 0       NaN                                   NaN       NaN
# 1        18  Senior Executive (C-Suite, VP, etc.)       Yes
# 2        27                   Developer, back-end       Yes
# 3        12                  Developer, front-end       Yes
# 4         6                 Developer, full-stack        No

# %%
#1) add column
df_mod['SOAccount_Bool'] = df_mod['SOAccount'].astype(str).replace({'Yes':True,'No':False})
df_mod.head()
# Out:
# C:\Users\Eldora\AppData\Local\Temp\ipykernel_29008\4133017221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mod['SOAccount_Bool'] = df_mod['SOAccount'].astype(str).replace({'Yes':True,'No':False})
#    ResponseId              Age                                       EdLevel  \
# 0           1  18-24 years old                                           NaN
# 1           2  25-34 years old  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           3  45-54 years old  BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)
# 3           4  25-34 years old  BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)
# 4           5  25-34 years old  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#   YearsCode                               DevType SOAccount SOAccount_Bool
# 0       NaN                                   NaN       NaN            nan
# 1        18  Senior Executive (C-Suite, VP, etc.)       Yes           True
# 2        27                   Developer, back-end       Yes           True
# 3        12                  Developer, front-end       Yes           True
# 4         6                 Developer, full-stack        No          False

# %%
#2) drop column
df_mod.drop(columns=['EdLevel','YearsCode'])
# Out:
#        ResponseId                Age                               DevType  \
# 0               1    18-24 years old                                   NaN
# 1               2    25-34 years old  Senior Executive (C-Suite, VP, etc.)
# 2               3    45-54 years old                   Developer, back-end
# 3               4    25-34 years old                  Developer, front-end
# 4               5    25-34 years old                 Developer, full-stack
# ...           ...                ...                                   ...
# 28185       28186    25-34 years old                   Developer, back-end
# 28186       28187    45-54 years old                 Developer, full-stack
# 28187       28188    18-24 years old                                   NaN
# 28188       28189  65 years or older                 Developer, full-stack
# 28189       28190    25-34 years old                 Developer, full-stack
#
#       SOAccount SOAccount_Bool
# 0           NaN            nan
# 1           Yes           True
# 2           Yes           True
# 3           Yes           True
# 4            No          False
# ...         ...            ...
# 28185       Yes           True
# 28186       Yes           True
# 28187       Yes           True
# 28188       Yes           True
# 28189       Yes           True
#
# [28190 rows x 5 columns]

# %%
#3) conncat dataframe
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. 
# Use pandas.concat instead.
df_mod_v2 = df_mod.head(3)
df_mod_v3 = df_mod.tail(3)
df_mod_v4 = pd.concat([df_mod_v2,df_mod_v3],sort=True) # sort arg is used for column sorted

# %%
#4) remove rows with condition
filt_rm = df_mod_v4['Age'] == '25-34 years old'
df_mod_v4[filt_rm]
# Out:
#                    Age                               DevType  \
# 1      25-34 years old  Senior Executive (C-Suite, VP, etc.)
# 28189  25-34 years old                 Developer, full-stack
#
#                                             EdLevel  ResponseId SOAccount  \
# 1      Bachelor’s degree (B.A., B.S., B.Eng., etc.)           2       Yes
# 28189  Bachelor’s degree (B.A., B.S., B.Eng., etc.)       28190       Yes
#
#       SOAccount_Bool YearsCode
# 1               True        18
# 28189           True        20

# %%
df_mod_v4.drop(index=df_mod_v4[filt_rm].index,inplace=True)
df_mod_v4
# Out:
#                      Age                DevType  \
# 0        18-24 years old                    NaN
# 2        45-54 years old    Developer, back-end
# 28187    18-24 years old                    NaN
# 28188  65 years or older  Developer, full-stack
#
#                                                EdLevel  ResponseId SOAccount  \
# 0                                                  NaN           1       NaN
# 2         BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)           3       Yes
# 28187   Professional degree (JD, MD, Ph.D, Ed.D, etc.)       28188       Yes
# 28188  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       28189       Yes
#
#       SOAccount_Bool YearsCode
# 0                nan       NaN
# 2               True        27
# 28187           True         7
# 28188           True        41

# %% [markdown]
# ## Sort Data

# %%
df_mod_v4.sort_values(by=['ResponseId','YearsCode'],ascending=[True,False],inplace=True)
df_mod_v4
# Out:
#                      Age                DevType  \
# 0        18-24 years old                    NaN
# 2        45-54 years old    Developer, back-end
# 28187    18-24 years old                    NaN
# 28188  65 years or older  Developer, full-stack
#
#                                                EdLevel  ResponseId SOAccount  \
# 0                                                  NaN           1       NaN
# 2         BACHELOR’S DEGREE (B.A., B.S., B.ENG., ETC.)           3       Yes
# 28187   Professional degree (JD, MD, Ph.D, Ed.D, etc.)       28188       Yes
# 28188  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       28189       Yes
#
#       SOAccount_Bool YearsCode
# 0                nan       NaN
# 2               True        27
# 28187           True         7
# 28188           True        41

# %%
df_mod_v4['ResponseId'].nlargest(2)
# Out:
# 28188    28189
# 28187    28188
# Name: ResponseId, dtype: int64

# %%
df_mod_v4.nlargest(2,'ResponseId')
# Out:
#                      Age                DevType  \
# 28188  65 years or older  Developer, full-stack
# 28187    18-24 years old                    NaN
#
#                                                EdLevel  ResponseId SOAccount  \
# 28188  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       28189       Yes
# 28187   Professional degree (JD, MD, Ph.D, Ed.D, etc.)       28188       Yes
#
#       SOAccount_Bool YearsCode
# 28188           True        41
# 28187           True         7

# %% [markdown]
# ## Grouping & Aggregate

# %%
df['ConvertedCompYearly'].nlargest(2)
# Out:
# 28121    57513831.0
# 19679    36573181.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].median()
# Out:
# 74963.0

# %%
#analyze data
df.median()
# Out:
# C:\Users\Eldora\AppData\Local\Temp\ipykernel_29008\3195619074.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# ResponseId              14095.5
# CompTotal              108000.0
# WorkExp                     9.0
# ConvertedCompYearly     74963.0
# dtype: float64

# %%
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  28190.000000  1.638200e+04  14745.000000         1.632100e+04
# mean   14095.500000  6.104261e+16     11.411055         9.929698e+04
# std     8137.896381  7.812977e+18      8.711165         5.452339e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%     7048.250000  6.000000e+04      5.000000         4.607100e+04
# 50%    14095.500000  1.080000e+05      9.000000         7.496300e+04
# 75%    21142.750000  2.250000e+05     16.000000         1.177980e+05
# max    28190.000000  1.000000e+21     50.000000         5.751383e+07

# %%
df['ConvertedCompYearly'].count()
# Out:
# 16321

# %%
df['ConvertedCompYearly'].value_counts().sum()
# Out:
# 16321

# %%
df['SOAccount'].map({'Yes':True,'No':False}).count() #exclude NaN value
# Out:
# 25943

# %%
df['SOAccount'].map({'Yes':True,'No':False}).value_counts() # also exclude NaN value, but separate the uniq value
# Out:
# True     22658
# False     3285
# Name: SOAccount, dtype: int64

# %%
#group by data
df.groupby('Country').get_group('China').head(2)['Country']
# Out:
# 67     China
# 152    China
# Name: Country, dtype: object

# %%
df.groupby('Country').get_group('China')['AIDevWantToWorkWith'].dropna().value_counts().nlargest()
# Out:
# GitHub Copilot            42
# GitHub Copilot;Tabnine     5
# Tabnine                    4
# AWS CodeWhisperer          3
# Mintlify                   2
# Name: AIDevWantToWorkWith, dtype: int64

# %%
df.groupby('Country')['CompTotal'].agg('mean').nlargest(5)
# Out:
# Country
# Iran, Islamic Republic of...    1.041667e+19
# Pakistan                        5.311760e+10
# Mali                            1.119896e+10
# Viet Nam                        4.087862e+08
# Bangladesh                      2.843817e+08
# Name: CompTotal, dtype: float64

# %%
df.loc[(df['Country'] == 'China') & (df['CompTotal'] > 0) ]['CompTotal'].agg(['max','min'])
# Out:
# max    2000000.0
# min         10.0
# Name: CompTotal, dtype: float64

# %%
df.groupby('Country')['LanguageHaveWorkedWith'].str.contains('Python')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29008\329779528.py in <module>
# ----> 1 df.groupby('Country')['LanguageHaveWorkedWith'].str.contains('Python')
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     902             return self[attr]
#     903
# --> 904         raise AttributeError(
#     905             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
#str apply to each series in the group
df.groupby('Country')['LanguageHaveWorkedWith'].apply(lambda x:x.str.contains('Python').sum()).nlargest()
# Out:
# Country
# United States of America                                2568
# Germany                                                 1292
# United Kingdom of Great Britain and Northern Ireland    1016
# India                                                    747
# France                                                   506
# Name: LanguageHaveWorkedWith, dtype: int64

# %% [markdown]
# ## Casting Datatypes and Handling Missing Values

# %%
#1）drop nan
df_drop = df[['ResponseId','Age','EdLevel','CompTotal']].head(10)
df_drop
# Out:
#    ResponseId              Age  \
# 0           1  18-24 years old
# 1           2  25-34 years old
# 2           3  45-54 years old
# 3           4  25-34 years old
# 4           5  25-34 years old
# 5           6  35-44 years old
# 6           7  35-44 years old
# 7           8  25-34 years old
# 8           9  45-54 years old
# 9          10  25-34 years old
#
#                                              EdLevel  CompTotal
# 0                                                NaN        NaN
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   285000.0
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   250000.0
# 3       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   156000.0
# 4       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  1320000.0
# 5  Some college/university study without earning ...    78000.0
# 6  Some college/university study without earning ...   135000.0
# 7       Bachelor’s degree (B.A., B.S., B.Eng., etc.)    80000.0
# 8    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)    60000.0
# 9       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        NaN

# %%
#axis=index is to drop the row; axis=column is to drop the column
df_drop.dropna(axis='index',how='any')
# Out:
#    ResponseId              Age  \
# 1           2  25-34 years old
# 2           3  45-54 years old
# 3           4  25-34 years old
# 4           5  25-34 years old
# 5           6  35-44 years old
# 6           7  35-44 years old
# 7           8  25-34 years old
# 8           9  45-54 years old
#
#                                              EdLevel  CompTotal
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   285000.0
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   250000.0
# 3       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   156000.0
# 4       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  1320000.0
# 5  Some college/university study without earning ...    78000.0
# 6  Some college/university study without earning ...   135000.0
# 7       Bachelor’s degree (B.A., B.S., B.Eng., etc.)    80000.0
# 8    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)    60000.0

# %%
#subset is to specify the columns to be check na
df_drop.dropna(axis='index',how='any',subset=['EdLevel'],inplace=True)

# %%
#2) convert type
df_drop.dtypes #dtypes is the dataframe's attribute
# Out:
# ResponseId      int64
# Age            object
# EdLevel        object
# CompTotal     float64
# dtype: object

# %%
df_drop['CompTotal'].astype(int)  #Cannot convert non-finite values (NA or inf) to integer
df_drop
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29008\2131539630.py in <module>
# ----> 1 df_drop['CompTotal'].astype(int)  #Cannot convert non-finite values (NA or inf) to integer
#       2 df_drop
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     578         values = self.values
#     579
# --> 580         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     581
#     582         new_values = maybe_coerce_values(new_values)
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1290
#    1291     try:
# -> 1292         new_values = astype_array(values, dtype, copy=copy)
#    1293     except (ValueError, TypeError):
#    1294         # e.g. astype_nansafe can fail on object-dtype of strings
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1235
#    1236     else:
# -> 1237         values = astype_nansafe(values, dtype, copy=copy)
#    1238
#    1239     # in pandas we don't store numpy str dtypes, so convert to object
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1146
#    1147     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1148         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1149
#    1150     elif is_object_dtype(arr.dtype):
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1191     """
#    1192     if not np.isfinite(values).all():
# -> 1193         raise IntCastingNaNError(
#    1194             "Cannot convert non-finite values (NA or inf) to integer"
#    1195         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
#fill the na value to be other value
df_drop['CompTotal'].fillna(0,inplace=True)
df_drop['EdLevel'].fillna('MISSING',inplace=True)
df_drop['CompTotal'] = df_drop['CompTotal'].astype(int)
df_drop.dtypes
# Out:
# ResponseId     int64
# Age           object
# EdLevel       object
# CompTotal      int32
# dtype: object

# %% [markdown]
# ## Working with Dates and Time Series Data

# %%
df_dt = pd.read_csv('data/ETH_1h.csv')
df_dt
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df_dt.loc[0,'Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29008\407897289.py in <module>
# ----> 1 df_dt.loc[0,'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
#1) parse the Date column from specific format to datetime format 
pd.to_datetime(df_dt['Date'],format='%Y-%m-%d %I-%p')
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
#2) parse and change to the datetime formate when loading
d_parser = lambda x:pd.datetime.strptime(x,'%Y-%m-%d %I-%p')
df_dt_2 = pd.read_csv('data/ETH_1h.csv',parse_dates=['Date'],date_parser=d_parser)
df_dt_2.head(2)
# Out:
# C:\Users\Eldora\AppData\Local\Temp\ipykernel_29008\157042207.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x:pd.datetime.strptime(x,'%Y-%m-%d %I-%p')
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09

# %%
from datetime import datetime 
d_parser = lambda x:datetime.strptime(x,'%Y-%m-%d %I-%p')
df_dt_2 = pd.read_csv('data/ETH_1h.csv',parse_dates=['Date'],date_parser=d_parser)
df_dt_2.head(2)
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09

# %%
#3) add day of week column by using th day_name() method of dt class
df_dt_2['DayofWeek'] = df_dt_2['Date'].dt.day_name()
df_dt_2.head(2)
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume  \
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
#
#   DayofWeek
# 0    Friday
# 1    Friday

# %%
#4) resample series/dataframe
'''
TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'
df_dt_2['High'].resample('1D')
solution: need to set DatetimeIndex first
''' 
df_dt_2.set_index('Date',inplace=True)
df_dt_2['High'].resample('W').max()
# Out:
# Date
# 2017-07-02    293.73
# 2017-07-09    285.00
# 2017-07-16    240.33
# 2017-07-23    249.40
# 2017-07-30    229.99
#                ...
# 2020-02-16    290.00
# 2020-02-23    287.13
# 2020-03-01    278.13
# 2020-03-08    253.01
# 2020-03-15    208.65
# Freq: W-SUN, Name: High, Length: 142, dtype: float64

# %%
df_dt_2.resample('W').agg({'High':'max','Low':'min','Close':'mean','Volume':'sum'})
# Out:
#               High     Low       Close        Volume
# Date
# 2017-07-02  293.73  253.23  268.202162  8.084631e+07
# 2017-07-09  285.00  231.25  261.062083  2.246746e+08
# 2017-07-16  240.33  130.26  195.698393  5.017750e+08
# 2017-07-23  249.40  153.25  212.783750  7.221637e+08
# 2017-07-30  229.99  178.03  203.309524  2.657305e+08
# ...            ...     ...         ...           ...
# 2020-02-16  290.00  216.31  255.198452  3.912867e+08
# 2020-02-23  287.13  242.36  265.321905  3.067838e+08
# 2020-03-01  278.13  209.26  236.373988  3.693920e+08
# 2020-03-08  253.01  196.00  229.817619  2.736569e+08
# 2020-03-15  208.65   90.00  176.332821  4.983998e+08
#
# [142 rows x 4 columns]

# %%
#5) directly access the datetime after setting index
#slice date range
df_dt_2['2019':'2020']
#minus date
df_dt_2.loc['2020-03','High'].max()
# Out:
# 253.01

# %%
#6) plot the dataframe
# %matplotlib inline

# %%
df_dt_2.loc['2020-03','High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Read & Write data to CSV/Excel/JSON

# %%
#1) write to csv
df_dt_2.to_csv('data/df_dt_2.csv',sep=',',encoding='utf-8')

# %%
#2) write to excel
df_dt_2.to_excel('data/df_dt_2.xlsx',header=True,encoding='utf-8',index=False)

# %%
#3) read from excel
df_dt_xlsx = pd.read_excel('data/df_dt_2.xlsx')
df_dt_xlsx.head()
# Out:
#    Symbol    Open    High     Low   Close      Volume DayofWeek
# 0  ETHUSD  129.94  131.82  126.87  128.71  1940673.93    Friday
# 1  ETHUSD  119.51  132.02  117.10  129.94  7579741.09    Friday
# 2  ETHUSD  124.47  124.85  115.50  119.51  4898735.81    Friday
# 3  ETHUSD  124.08  127.42  121.63  124.47  2753450.92    Friday
# 4  ETHUSD  124.85  129.51  120.17  124.08  4461424.71    Friday

# %%
#4) write to json
df_dt_2.to_json('data/df_dt_2.json',orient='records',indent=4,lines=False)

# %%
#5) read from json
df_dt_json = pd.read_json('data/df_dt_2.json')
df_dt_json.head()
# Out:
#    Symbol    Open    High     Low   Close      Volume DayofWeek
# 0  ETHUSD  129.94  131.82  126.87  128.71  1940673.93    Friday
# 1  ETHUSD  119.51  132.02  117.10  129.94  7579741.09    Friday
# 2  ETHUSD  124.47  124.85  115.50  119.51  4898735.81    Friday
# 3  ETHUSD  124.08  127.42  121.63  124.47  2753450.92    Friday
# 4  ETHUSD  124.85  129.51  120.17  124.08  4461424.71    Friday
